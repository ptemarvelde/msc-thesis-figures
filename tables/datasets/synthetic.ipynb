# %%
import pandas as pd
from figure_utils import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
SAVE = False
df = read_data_chars(type_="synthetic", base_path=f"{RESULT_DIR}/daic")
# Out:
# reading /mnt/c/Users/ptema/Documents/uni/y5/amalur-experiments/results/full_1/daic/features/data_chars_synthetic.jsonl

# %%
fig, axs = plt.subplots(4,3, figsize = (10,10))
for col, ax in zip([x for x in df.columns if np.issubdtype(df[x].dtype, np.number)], axs.flatten()):
    sns.histplot(df[col], ax=ax)
    ax.set_title(col)
fig.tight_layout()
